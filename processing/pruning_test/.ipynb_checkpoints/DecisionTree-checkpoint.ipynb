# %%
import numpy as np
import scipy as sp
import sklearn
import csv
import matplotlib.pyplot as plt
from sklearn.cross_validation import KFold
from sklearn.cross_validation import ShuffleSplit
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import train_test_split
from sklearn.tree import export_graphviz
from IPython.display import Image
# from sklearn.naive_bayes import GaussianNB
# from sklearn.metrics import precision_score
# from sklearn.metrics import roc_auc_score
# from sklearn.metrics import confusion_matrix
# from sklearn import cross_validation
import StringIO, pydot

### reading csv file into list of lists, header and main body of the data
# data = []
# c = 0
# with open('output.csv', 'rU') as f:  #opens PW file
#     reader = csv.reader(f)
#     for row in reader:
#     	if c == 0:
#     		head = row
#     		c = 1
#     	else:
#     		data.append(row)
# # print len(data)
# data = np.asarray(data)
# # print data_arr.shape

# numFeatures = len(head)
# numInstances = len(data)
# # print numFeatures, numInstances


# ### delect the first attribute, 'id', attributes contains all the attributes need to fit the model
# attributes = data[:,3:]
# target = data[:,2]
# # print attributes.shape
# # print target.shape


# ### randomly pick up training set and testing set
# Xtrain, Xtest, ytrain, ytest = train_test_split(attributes, target, train_size=666, test_size=333, random_state=42)
data = []
c = 0
with open(file, 'rU') as f:  #opens PW file
    reader = csv.reader(f)
    for row in reader:
        if c == 0:
            head = row
            c = 1
        else:
            data.append(row)
# print len(data)
data = np.asarray(data)
# print data_arr.shape
data = data[1:5000,:]

	# numFeatures = len(head)
	# numInstances = len(data)

	# feature contains all the covariates, feature_dct: feature_name: the column_position of the feature
feature = head[2:]
feature_id = np.arange(len(feature))
feature_dct = dict(zip(feature,feature_id))


	### delect the first attribute, 'id', attributes contains all the attributes need to fit the model
splilt = data[:,0]

	### select the test and train dataset according to the 'test'. '1' = test, '0' = train
Xtrain = data[splilt=='0',2:]
ytrain = data[splilt=='0',1]
Xtest = data[splilt =='1',2:]
ytest = data[splilt =='1',1]
### build up the tree and using split-testing data to test
clf = tree.DecisionTreeClassifier(criterion='entropy', min_samples_leaf = 1, max_depth=20)
clf = clf.fit(Xtrain, ytrain)
# myPredictions = clf.predict(Xtest)
# correctClass = accuracy_score(ytest, myPredictions)
# print correctClass

dot_data = StringIO.StringIO()
export_graphviz(clf, out_file=dot_data)
# print dot_data.getvalue()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d70d8c3408ef> in <module>()
#      49 data = []
#      50 c = 0
# ---> 51 with open(file, 'rU') as f:  #opens PW file
#      52     reader = csv.reader(f)
#      53     for row in reader:
#
# TypeError: coercing to Unicode: need string or buffer, type found

# %%
def viz(decision_tree, feature_names=None):
  from warnings import warn
 
  js = ""
 
  def node_to_str(tree, node_id, criterion):
    if not isinstance(criterion, sklearn.tree.tree.six.string_types):
      criterion = "impurity"
 
    value = tree.value[node_id]
    if tree.n_outputs == 1:
      value = value[0, :]
 
    if tree.children_left[node_id] == sklearn.tree._tree.TREE_LEAF:
      return '"id": "%s", "criterion": "%s", "impurity": "%s", "samples": "%s", "value": "%s"' \
             % (node_id, 
                criterion,
                tree.impurity[node_id],
                tree.n_node_samples[node_id],
                value)
    else:
      if feature_names is not None:
        feature = feature_names[tree.feature[node_id]]
      else:
        feature = tree.feature[node_id]
 
      return '"id": "%s", "rule": "%s <= %.4f", "%s": "%s", "samples": "%s"' \
             % (node_id, 
                feature,
                tree.threshold[node_id],
                criterion,
                tree.impurity[node_id],
                tree.n_node_samples[node_id])
 
  def recurse(tree, node_id, criterion, parent=None, depth=0):
    tabs = "  " * depth
    js = ""
 
    left_child = tree.children_left[node_id]
    right_child = tree.children_right[node_id]
 
    js = js + "\n" + \
         tabs + "{\n" + \
         tabs + "  " + node_to_str(tree, node_id, criterion)
 
    if left_child != sklearn.tree._tree.TREE_LEAF:
      js = js + ",\n" + \
           tabs + '  "left": ' + \
           recurse(tree, \
                   left_child, \
                   criterion=criterion, \
                   parent=node_id, \
                   depth=depth + 1) + ",\n" + \
           tabs + '  "right": ' + \
           recurse(tree, \
                   right_child, \
                   criterion=criterion, \
                   parent=node_id,
                   depth=depth + 1)
 
    js = js + tabs + "\n" + \
         tabs + "}"
 
    return js
 
  if isinstance(decision_tree, sklearn.tree.tree.Tree):
    js = js + recurse(decision_tree, 0, criterion="impurity")
  else:
    js = js + recurse(decision_tree.tree_, 0, criterion=decision_tree.criterion)
 
  return js

# %%
print viz(clf, feature_names=head)
# Out:
# {
#   "id": "0", "rule": "test <= 0.5000", "entropy": "0.750398617197", "samples": "666",
#   "left":
#   {
#     "id": "1", "rule": "info__age_80_90 <= 0.5000", "entropy": "0.85523740464", "samples": "511",
#     "left":
#     {
#       "id": "2", "rule": "outcome <= 0.5000", "entropy": "0.877195234233", "samples": "482",
#       "left":
#       {
#         "id": "3", "rule": "info__age_60_70 <= 0.5000", "entropy": "0.899614112465", "samples": "453",
#         "left":
#         {
#           "id": "4", "rule": "diagnosis__HIERARCHY_10.1.8 <= 0.5000", "entropy": "0.921401189764", "samples": "425",
#           "left":
#           {
#             "id": "5", "rule": "info__age_50_60 <= 0.5000", "entropy": "0.909228416257", "samples": "416",
#             "left":
#             {
#               "id": "6", "rule": "info__age_90_100 <= 0.5000", "entropy": "0.919118707679", "samples": "404",
#               "left":
#               {
#                 "id": "7", "rule": "diagnosis__HIERARCHY_3.2 <= 0.5000", "entropy": "0.928955724869", "samples": "392",
#                 "left":
#                 {
#                   "id": "8", "rule": "diagnosis__HIERARCHY_9.11 <= 0.5000", "entropy": "0.935455764558", "samples": "384",
#                   "left":
#                   {
#                     "id": "9", "rule": "diagnosis__HIERARCHY_9.12.3 <= 0.5000", "entropy": "0.947274164756", "samples": "361",
#                     "left":
#                     {
#                       "id": "10", "rule": "diagnosis__HIERARCHY_6.4 <= 0.5000", "entropy": "0.905789171568", "samples": "277",
#                       "left":
#                       {
#                         "id": "11", "rule": "diagnosis__HIERARCHY_6.8.2 <= 0.5000", "entropy": "0.89181075438", "samples": "272",
#                         "left":
#                         {
#                           "id": "12", "rule": "diagnosis__HIERARCHY_8.6.1 <= 0.5000", "entropy": "0.909022156088", "samples": "259",
#                           "left":
#                           {
#                             "id": "13", "rule": "diagnosis__HIERARCHY_9.5 <= 0.5000", "entropy": "0.897427193088", "samples": "255",
#                             "left":
#                             {
#                               "id": "14", "rule": "diagnosis__HIERARCHY_7.1.2.2 <= 0.5000", "entropy": "0.882758678796", "samples": "249",
#                               "left":
#                               {
#                                 "id": "15", "rule": "diagnosis__HIERARCHY_13.3.3 <= 0.5000", "entropy": "0.872161788341", "samples": "246",
#                                 "left":
#                                 {
#                                   "id": "16", "rule": "diagnosis__78900 <= 0.5000", "entropy": "0.885883479048", "samples": "237",
#                                   "left":
#                                   {
#                                     "id": "17", "rule": "diagnosis__2720 <= 0.5000", "entropy": "0.871093275317", "samples": "233",
#                                     "left":
#                                     {
#                                       "id": "18", "rule": "diagnosis__HIERARCHY_8.3.2 <= 0.5000", "entropy": "0.858981037043", "samples": "230",
#                                       "left":
#                                       {
#                                         "id": "19", "rule": "diagnosis__HIERARCHY_2.12 <= 0.5000", "entropy": "0.843054496334", "samples": "225",
#                                         "left":
#                                         {
#                                           "id": "20", "criterion": "entropy", "impurity": "0.833570444002", "samples": "223", "value": "[ 164.   59.]"
#                                         },
#                                         "right":
#                                         {
#                                           "id": "21", "criterion": "entropy", "impurity": "0.0", "samples": "2", "value": "[ 0.  2.]"
#                                         }
#                                       },
#                                       "right":
#                                       {
#                                         "id": "22", "rule": "diagnosis__HIERARCHY_8.1.5.4 <= 0.5000", "entropy": "0.721928094887", "samples": "5",
#                                         "left":
#                                         {
#                                           "id": "23", "criterion": "entropy", "impurity": "0.0", "samples": "4", "value": "[ 0.  4.]"
#                                         },
#                                         "right":
#                                         {
#                                           "id": "24", "criterion": "entropy", "impurity": "0.0", "samples": "1", "value": "[ 1.  0.]"
#                                         }
#                                       }
#                                     },
#                                     "right":
#                                     {
#                                       "id": "25", "criterion": "entropy", "impurity": "0.0", "samples": "3", "value": "[ 0.  3.]"
#                                     }
#                                   },
#                                   "right":
#                                   {
#                                     "id": "26", "criterion": "entropy", "impurity": "0.0", "samples": "4", "value": "[ 0.  4.]"
#                                   }
#                                 },
#                                 "right":
#                                 {
#                                   "id": "27", "criterion": "entropy", "impurity": "0.0", "samples": "9", "value": "[ 9.  0.]"
#                                 }
#                               },
#                               "right":
#                               {
#                                 "id": "28", "criterion": "entropy", "impurity": "0.0", "samples": "3", "value": "[ 0.  3.]"
#                               }
#                             },
#                             "right":
#                             {
#                               "id": "29", "rule": "diagnosis__HIERARCHY_5.8.1 <= 0.5000", "entropy": "0.650022421648", "samples": "6",
#                               "left":
#                               {
#                                 "id": "30", "criterion": "entropy", "impurity": "0.0", "samples": "5", "value": "[ 0.  5.]"
#                               },
#                               "right":
#                               {
#                                 "id": "31", "criterion": "entropy", "impurity": "0.0", "samples": "1", "value": "[ 1.  0.]"
#                               }
#                             }
#                           },
#                           "right":
#                           {
#                             "id": "32", "criterion": "entropy", "impurity": "0.0", "samples": "4", "value": "[ 0.  4.]"
#                           }
#                         },
#                         "right":
#                         {
#                           "id": "33", "criterion": "entropy", "impurity": "0.0", "samples": "13", "value": "[ 13.   0.]"
#                         }
#                       },
#                       "right":
#                       {
#                         "id": "34", "criterion": "entropy", "impurity": "0.0", "samples": "5", "value": "[ 0.  5.]"
#                       }
#                     },
#                     "right":
#                     {
#                       "id": "35", "rule": "diagnosis__HIERARCHY_2.1.1 <= 0.5000", "entropy": "0.999591034189", "samples": "84",
#                       "left":
#                       {
#                         "id": "36", "rule": "diagnosis__HIERARCHY_13.6.1 <= 0.5000", "entropy": "0.996956251847", "samples": "77",
#                         "left":
#                         {
#                           "id": "37", "rule": "diagnosis__7823 <= 0.5000", "entropy": "0.999856899153", "samples": "71",
#                           "left":
#                           {
#                             "id": "38", "rule": "diagnosis__78841 <= 0.5000", "entropy": "0.994030211477", "samples": "66",
#                             "left":
#                             {
#                               "id": "39", "rule": "diagnosis__HIERARCHY_16.6.1 <= 0.5000", "entropy": "0.999249247996", "samples": "62",
#                               "left":
#                               {
#                                 "id": "40", "rule": "diagnosis__HIERARCHY_3.8.4 <= 0.5000", "entropy": "0.98410952788", "samples": "54",
#                                 "left":
#                                 {
#                                   "id": "41", "rule": "diagnosis__HIERARCHY_6.2.1 <= 0.5000", "entropy": "0.998747297936", "samples": "48",
#                                   "left":
#                                   {
#                                     "id": "42", "rule": "diagnosis__7231 <= 0.5000", "entropy": "0.986544630006", "samples": "44",
#                                     "left":
#                                     {
#                                       "id": "43", "rule": "diagnosis__5533 <= 0.5000", "entropy": "0.999525689294", "samples": "39",
#                                       "left":
#                                       {
#                                         "id": "44", "rule": "diagnosis__HIERARCHY_13.3.3 <= 0.5000", "entropy": "0.991076059838", "samples": "36",
#                                         "left":
#                                         {
#                                           "id": "45", "criterion": "entropy", "impurity": "0.999249247996", "samples": "31", "value": "[ 16.  15.]"
#                                         },
#                                         "right":
#                                         {
#                                           "id": "46", "criterion": "entropy", "impurity": "0.0", "samples": "5", "value": "[ 0.  5.]"
#                                         }
#                                       },
#                                       "right":
#                                       {
#                                         "id": "47", "criterion": "entropy", "impurity": "0.0", "samples": "3", "value": "[ 3.  0.]"
#                                       }
#                                     },
#                                     "right":
#                                     {
#                                       "id": "48", "criterion": "entropy", "impurity": "0.0", "samples": "5", "value": "[ 0.  5.]"
#                                     }
#                                   },
#                                   "right":
#                                   {
#                                     "id": "49", "criterion": "entropy", "impurity": "0.0", "samples": "4", "value": "[ 4.  0.]"
#                                   }
#                                 },
#                                 "right":
#                                 {
#                                   "id": "50", "criterion": "entropy", "impurity": "0.0", "samples": "6", "value": "[ 0.  6.]"
#                                 }
#                               },
#                               "right":
#                               {
#                                 "id": "51", "rule": "diagnosis__HIERARCHY_16.2.5 <= 0.5000", "entropy": "0.5435644432", "samples": "8",
#                                 "left":
#                                 {
#                                   "id": "52", "criterion": "entropy", "impurity": "0.0", "samples": "7", "value": "[ 7.  0.]"
#                                 },
#                                 "right":
#                                 {
#                                   "id": "53", "criterion": "entropy", "impurity": "0.0", "samples": "1", "value": "[ 0.  1.]"
#                                 }
#                               }
#                             },
#                             "right":
#                             {
#                               "id": "54", "criterion": "entropy", "impurity": "0.0", "samples": "4", "value": "[ 0.  4.]"
#                             }
#                           },
#                           "right":
#                           {
#                             "id": "55", "criterion": "entropy", "impurity": "0.0", "samples": "5", "value": "[ 5.  0.]"
#                           }
#                         },
#                         "right":
#                         {
#                           "id": "56", "criterion": "entropy", "impurity": "0.0", "samples": "6", "value": "[ 6.  0.]"
#                         }
#                       },
#                       "right":
#                       {
#                         "id": "57", "criterion": "entropy", "impurity": "0.0", "samples": "7", "value": "[ 0.  7.]"
#                       }
#                     }
#                   },
#                   "right":
#                   {
#                     "id": "58", "rule": "diagnosis__HIERARCHY_6.9.2 <= 0.5000", "entropy": "0.558629373452", "samples": "23",
#                     "left":
#                     {
#                       "id": "59", "rule": "diagnosis__HIERARCHY_7 <= 0.5000", "entropy": "0.276195427648", "samples": "21",
#                       "left":
#                       {
#                         "id": "60", "criterion": "entropy", "impurity": "0.0", "samples": "1", "value": "[ 0.  1.]"
#                       },
#                       "right":
#                       {
#                         "id": "61", "criterion": "entropy", "impurity": "0.0", "samples": "20", "value": "[ 20.   0.]"
#                       }
#                     },
#                     "right":
#                     {
#                       "id": "62", "criterion": "entropy", "impurity": "0.0", "samples": "2", "value": "[ 0.  2.]"
#                     }
#                   }
#                 },
#                 "right":
#                 {
#                   "id": "63", "criterion": "entropy", "impurity": "0.0", "samples": "8", "value": "[ 8.  0.]"
#                 }
#               },
#               "right":
#               {
#                 "id": "64", "criterion": "entropy", "impurity": "0.0", "samples": "12", "value": "[ 12.   0.]"
#               }
#             },
#             "right":
#             {
#               "id": "65", "criterion": "entropy", "impurity": "0.0", "samples": "12", "value": "[ 12.   0.]"
#             }
#           },
#           "right":
#           {
#             "id": "66", "rule": "diagnosis__HIERARCHY_10.3.1 <= 0.5000", "entropy": "0.503258334776", "samples": "9",
#             "left":
#             {
#               "id": "67", "criterion": "entropy", "impurity": "0.0", "samples": "8", "value": "[ 0.  8.]"
#             },
#             "right":
#             {
#               "id": "68", "criterion": "entropy", "impurity": "0.0", "samples": "1", "value": "[ 1.  0.]"
#             }
#           }
#         },
#         "right":
#         {
#           "id": "69", "criterion": "entropy", "impurity": "0.0", "samples": "28", "value": "[ 28.   0.]"
#         }
#       },
#       "right":
#       {
#         "id": "70", "criterion": "entropy", "impurity": "0.0", "samples": "29", "value": "[ 29.   0.]"
#       }
#     },
#     "right":
#     {
#       "id": "71", "criterion": "entropy", "impurity": "0.0", "samples": "29", "value": "[ 29.   0.]"
#     }
#   },
#   "right":
#   {
#     "id": "72", "criterion": "entropy", "impurity": "0.0", "samples": "155", "value": "[ 155.    0.]"
#   }
# }
